# %%
import pandas as pd
ipl_data = pd.read_csv(r"/home/pavandeep_369/Downloads/IPL.csv")
# Out:
# /tmp/ipykernel_60696/2562022759.py:2: DtypeWarning: Columns (0: review_batter, 1: team_reviewed, 2: review_decision, 3: umpire, 4: season, 5: superover_winner, 6: result_type, 7: method, 8: event_match_no) have mixed types. Specify dtype option on import or set low_memory=False.
#   ipl_data = pd.read_csv(r"/home/pavandeep_369/Downloads/IPL.csv")

# %%
#2. Select only the necessary columns
required_columns = [
    'match_id', 'date', 'match_type', 'season','year','over','ball','valid_ball','runs_bowler','runs_total',
    'batter', 'bowler', 'runs_batter', 'bowler_wicket','player_out','bat_pos',
    'batting_team', 'bowling_team', 'wicket_kind'
]

# Create optimized dataframe
ball2ball_df = ipl_data[required_columns].copy()

# 3. Export to a smaller CSV file
ball2ball_df.to_csv("ball2ball_df.csv", index=False)

# %%
ball2ball_df[ball2ball_df['season']==2016].head(10)
# Out:
#         match_id        date match_type season  year  over  ball       batter  \
# 122502    980901  2016-04-09        T20   2016  2016     0     1  LMP Simmons
# 122503    980901  2016-04-09        T20   2016  2016     0     2    RG Sharma
# 122504    980901  2016-04-09        T20   2016  2016     0     3    RG Sharma
# 122505    980901  2016-04-09        T20   2016  2016     0     4    RG Sharma
# 122506    980901  2016-04-09        T20   2016  2016     0     5    RG Sharma
# 122507    980901  2016-04-09        T20   2016  2016     0     6  LMP Simmons
# 122508    980901  2016-04-09        T20   2016  2016     1     1    RG Sharma
# 122509    980901  2016-04-09        T20   2016  2016     1     2    HH Pandya
# 122510    980901  2016-04-09        T20   2016  2016     1     2    HH Pandya
# 122511    980901  2016-04-09        T20   2016  2016     1     3    HH Pandya
#
#           bowler  runs_batter  bowler_wicket    batting_team  \
# 122502  RP Singh            1              0  Mumbai Indians
# 122503  RP Singh            0              0  Mumbai Indians
# 122504  RP Singh            2              0  Mumbai Indians
# 122505  RP Singh            4              0  Mumbai Indians
# 122506  RP Singh            1              0  Mumbai Indians
# 122507  RP Singh            0              0  Mumbai Indians
# 122508  I Sharma            0              1  Mumbai Indians
# 122509  I Sharma            0              0  Mumbai Indians
# 122510  I Sharma            0              0  Mumbai Indians
# 122511  I Sharma            0              0  Mumbai Indians
#
#                    bowling_team wicket_kind
# 122502  Rising Pune Supergiants         NaN
# 122503  Rising Pune Supergiants         NaN
# 122504  Rising Pune Supergiants         NaN
# 122505  Rising Pune Supergiants         NaN
# 122506  Rising Pune Supergiants         NaN
# 122507  Rising Pune Supergiants         NaN
# 122508  Rising Pune Supergiants         lbw
# 122509  Rising Pune Supergiants         NaN
# 122510  Rising Pune Supergiants         NaN
# 122511  Rising Pune Supergiants         NaN
